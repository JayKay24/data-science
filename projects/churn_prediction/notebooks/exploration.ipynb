# %% [markdown]
# # Customer Churn Exploration
# Quick exploratory notebook verifying imports from `core` and `churn_prediction`.

# %%
from churn_prediction.features import prepare_synthetic_data
import pandas as pd

X, y = prepare_synthetic_data(100)
df = pd.concat([X, y], axis=1)
print(df.head())
